# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# Fredericton is the Capital City of the only Canadian fully-bilingual Province of New Brunswick and is located at the banks of the Saint John River. While one of the least populated provincial capital cities with a population base of less than 60 thousand residents, it offers a wide spectrum of venues and is a government, university and cultural hub.
# As the city grows and develops, it becomes increasingly important to examine and understand it. The City of Fredericton provides open data for everyone and encourages entrepreneurial use to develop services for the benefit of its citizens. The purpose of this Project is to help people in exploring better facilities around their neighborhood. It will help people making smart decision on selecting appropriate neighborhood. It will help people to get awareness of the area and neighborhood before moving to a new city, state, country or place for their work or to start a new fresh life. Developers, investors, policy makers and/or city planners have an interest in the need for additional services and citizen protection.

# %% [markdown]
# # PROBLEM

# %% [markdown]
# •	Which neighborhoods have the highest crime?
# •	Is population density correlated to crime level?
# •	Using foursquare data, what venues are most common in different locations within the city?
# •	Does the Knowledge Park really need a coffee shop?
